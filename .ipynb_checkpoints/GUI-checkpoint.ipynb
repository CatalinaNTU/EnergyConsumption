# %%
# !pip install ipywidgets

from IPython.display import display, clear_output
# !pip install --upgrade notebook ipywidgets

import ipywidgets as widgets
import tkinter as tk
from tkinter import ttk, messagebox
import numpy as np
widgets.IntSlider()
import pandas as pd
import numpy as np
import ipywidgets as widgets
from IPython.display import display, clear_output
import joblib
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: ipywidgets in c:\users\catas\anaconda3\lib\site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\catas\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\catas\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\catas\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\catas\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\catas\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\users\catas\anaconda3\lib\site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\catas\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\catas\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\catas\anaconda3\Lib\site-packages)
# Requirement already satisfied: notebook in c:\users\catas\anaconda3\lib\site-packages (7.4.6)
# Collecting notebook
#   Using cached notebook-7.4.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ipywidgets in c:\users\catas\anaconda3\lib\site-packages (8.1.7)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\catas\anaconda3\lib\site-packages (from notebook) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\catas\anaconda3\lib\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.9 in c:\users\catas\anaconda3\lib\site-packages (from notebook) (4.4.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\catas\anaconda3\lib\site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\catas\anaconda3\lib\site-packages (from notebook) (6.4.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\catas\anaconda3\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\catas\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (2.0.4)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (0.27.0)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (2.2.0)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab<4.5,>=4.4.9->notebook) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\catas\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\catas\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\catas\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\catas\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\catas\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook) (2024.1)
# Requirement already satisfied: certifi in c:\users\catas\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\catas\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\catas\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.9->notebook) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\catas\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\catas\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook) (1.6.0)
# Requirement already satisfied: psutil in c:\users\catas\anaconda3\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.9->notebook) (5.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\catas\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\catas\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\catas\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\catas\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\catas\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\catas\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\catas\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\catas\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\catas\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\catas\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\catas\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\catas\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\catas\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\catas\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\catas\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\catas\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\catas\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\catas\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\catas\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\catas\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.2.3)
# Requirement already satisfied: executing in c:\users\catas\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\catas\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\catas\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\catas\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\catas\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\catas\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\catas\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\catas\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.1)
# Requirement already satisfied: uri-template in c:\users\catas\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\catas\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\catas\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\catas\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: pycparser in c:\users\catas\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\catas\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.2.3)
# Using cached notebook-7.4.7-py3-none-any.whl (14.3 MB)
# Installing collected packages: notebook
#   Attempting uninstall: notebook
#     Found existing installation: notebook 7.4.6
#     Uninstalling notebook-7.4.6:
#       Successfully uninstalled notebook-7.4.6
# Successfully installed notebook-7.4.7
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\catas\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\catas\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\catas\anaconda3\Lib\site-packages)

# %%
try:
    ridge_model = joblib.load("Ridge_model.pkl")
    model_exists = True
    print("✅ Ridge model loaded successfully")
except:
    ridge_model = None
    model_exists = False
    print("⚠️ Ridge model not found. Using demo calculation.")

# Model features (exactly as in your training)
numerical_features = [
    'Temperature', 'Humidity', 'SquareFootage', 'Occupancy', 
    'HVACUsage', 'LightingUsage', 'DayOfWeek', 
    'Holiday', 'Hour', 'Day', 'Month'
]

# Create scaler with typical values (since we don't have the original)
scaler = StandardScaler()
typical_data = pd.DataFrame({
    'Temperature': [22.0], 'Humidity': [50.0], 'SquareFootage': [1500],
    'Occupancy': [5], 'HVACUsage': [0.5], 'LightingUsage': [0.5],
    'DayOfWeek': [4], 'Holiday': [0.1], 'Hour': [12], 'Day': [15], 'Month': [6]
})
scaler.fit(typical_data)

# Mappings
day_mapping = {
    'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 
    'Friday': 5, 'Saturday': 6, 'Sunday': 7
}
holiday_mapping = {'No': 0, 'Yes': 1}
hvac_mapping = {'Off': 0, 'On': 1}
lighting_mapping = {'Off': 0, 'On': 1}

# Widgets
day_of_week = widgets.Dropdown(
    options=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
    description="Day:"
)
holiday = widgets.Dropdown(options=['No', 'Yes'], description="Holiday:")
hour = widgets.IntSlider(
    value=12, min=0, max=23, step=1, description="Hour:"
)
day = widgets.IntSlider(
    value=15, min=1, max=31, step=1, description="Day:"
)
month = widgets.IntSlider(
    value=6, min=1, max=12, step=1, description="Month:"
)
temperature = widgets.FloatSlider(
    value=22.0, min=10, max=35, step=0.5, description="Temp (°C):"
)
humidity = widgets.FloatSlider(
    value=50.0, min=20, max=80, step=1.0, description="Humidity (%):"
)
square_footage = widgets.IntSlider(
    value=1500, min=500, max=5000, step=100, description="Area (ft²):"
)
occupancy = widgets.IntSlider(
    value=5, min=1, max=20, step=1, description="Occupancy:"
)
hvac_usage = widgets.Dropdown(options=['Off', 'On'], description="HVAC:")
lighting_usage = widgets.Dropdown(options=['Off', 'On'], description="Lighting:")

button = widgets.Button(description="🔮 Predict Energy", button_style="success")
output = widgets.Output()

def predict_callback(b):
    with output:
        clear_output()
        
        # Prepare input data using exact feature order
        input_dict = {}
        for feature in numerical_features:
            if feature == 'Temperature':
                input_dict[feature] = temperature.value
            elif feature == 'Humidity':
                input_dict[feature] = humidity.value
            elif feature == 'SquareFootage':
                input_dict[feature] = square_footage.value
            elif feature == 'Occupancy':
                input_dict[feature] = occupancy.value
            elif feature == 'HVACUsage':
                input_dict[feature] = hvac_mapping[hvac_usage.value]
            elif feature == 'LightingUsage':
                input_dict[feature] = lighting_mapping[lighting_usage.value]
            elif feature == 'DayOfWeek':
                input_dict[feature] = day_mapping[day_of_week.value]
            elif feature == 'Holiday':
                input_dict[feature] = holiday_mapping[holiday.value]
            elif feature == 'Hour':
                input_dict[feature] = hour.value
            elif feature == 'Day':
                input_dict[feature] = day.value
            elif feature == 'Month':
                input_dict[feature] = month.value
        
        input_data = pd.DataFrame([input_dict])[numerical_features]  # Ensure correct order
        
        if model_exists:
            # Use Ridge model
            input_scaled = scaler.transform(input_data)
            prediction = ridge_model.predict(input_scaled)[0]
            print(f"⚡ Predicted Energy Consumption: {prediction:.2f} kWh")
        else:
            # Demo calculation
            base = square_footage.value * 0.04
            temp_factor = abs(temperature.value - 22) * 2
            hvac_factor = 20 if hvac_usage.value == 'On' else 0
            lighting_factor = 8 if lighting_usage.value == 'On' else 0
            occupancy_factor = occupancy.value * 2
            
            prediction = base + temp_factor + hvac_factor + lighting_factor + occupancy_factor
            print(f"⚡ Demo Energy Consumption: {prediction:.2f} kWh")

button.on_click(predict_callback)

# Display interface
display(widgets.VBox([
    widgets.HBox([day_of_week, holiday]),
    widgets.HBox([hour, day, month]),
    temperature, humidity, square_footage, occupancy,
    widgets.HBox([hvac_usage, lighting_usage]),
    button, output
]))
# Out:
# ✅ Ridge model loaded successfully
# VBox(children=(HBox(children=(Dropdown(description='Day:', options=('Monday', 'Tuesday', 'Wednesday', 'Thursda…
